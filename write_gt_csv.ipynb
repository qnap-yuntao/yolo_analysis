# %%
# Output as csv file
import os
import csv
path = '/home/qeek/yolo/BBox-Label-Tool/conver_to_BBOX_val_ground_truth/'
file_list = os.listdir(path)
res = []

for file in file_list:
    if file.startswith('.'):
        file_list.remove(file)

with open('/home/qeek/yolo/CSV_file/gt_BBOX.csv', 'w') as output:
    writer = csv.writer(output)
    writer.writerow(['gt_label'])
    
for i in range(1,len(file_list)+1):
    res = []       
    s = ''
 
    if i < 10:
        file = '/home/qeek/yolo/BBox-Label-Tool/conver_to_BBOX_val_ground_truth/validation_00{}.txt'.format(i)
    elif i >= 10 and i < 100:
        file = '/home/qeek/yolo/BBox-Label-Tool/conver_to_BBOX_val_ground_truth/validation_0{}.txt'.format(i) 
    elif i >= 100:
        file = '/home/qeek/yolo/BBox-Label-Tool/conver_to_BBOX_val_ground_truth/validation_{}.txt'.format(i)
   
    with open(file,'r') as f:
        content = f.read()
        lines = content.split('\n')
        n = len(lines)-1
        for j in range(n):
            name = lines[j].split(' ')[0]   
            bbox = lines[j].split(' ')[1:]
            [xmin,ymin,xmax,ymax] = bbox
            s += name + ' '     
            s = s + ',' +  str(xmin) + ' ' + str(ymin) + ' ' + str(xmax) + ' ' + str(ymax) + ' ; '
        res.append(s[:-3])


    with open('/home/qeek/yolo/CSV_file/gt_BBOX.csv', 'a') as output:
        writer = csv.writer(output)
        writer.writerow(res)

# %%
# Combine with other csv file
import pandas as pd

df1 = pd.read_csv('/home/qeek/yolo/CSV_file/Predicting_BBOX.csv')
df2 = pd.read_csv('/home/qeek/yolo/CSV_file/gt_BBOX.csv')

result = pd.concat([df1, df2], axis=1, join_axes=[df1.index])

# %%
result.to_csv('/home/qeek/yolo/CSV_file/yolo_result.csv')

# %%
result
# Out:
#            img_name                                      predict_label  \
# 0    validation_001          3 ,1035 292 1451 624 ; 3 ,380 277 778 601
# 1    validation_002             2 ,427 640 587 780 ; 0 ,96 500 298 554
# 2    validation_003                                 0 ,706 427 926 489
# 3    validation_004                                0 ,630 226 1254 364
# 4    validation_005  1 ,914 623 1016 713 ; 1 ,1250 635 1334 721 ; 0...
# 5    validation_006  1 ,1076 565 1112 603 ; 1 ,1269 574 1309 612 ; ...
# 6    validation_007           0 ,839 527 1023 645 ; 2 ,515 607 639 745
# 7    validation_008           3 ,628 379 882 567 ; 3 ,981 387 1209 561
# 8    validation_009          0 ,1035 692 1241 796 ; 1 ,307 811 345 851
# 9    validation_010  1 ,804 663 928 765 ; 1 ,1194 723 1310 811 ; 0 ...
# 10   validation_011  1 ,401 386 447 436 ; 1 ,1471 473 1513 513 ; 1 ...
# 11   validation_012          0 ,1076 596 1158 756 ; 1 ,454 745 494 785
# ...
